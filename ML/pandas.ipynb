# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series Data Structure

# %%
s = pd.Series([4,5,6,'a','b','c',np.nan,0])

# %%
print(s)
# Out:
# 0      4
# 1      5
# 2      6
# 3      a
# 4      b
# 5      c
# 6    NaN
# 7      0
# dtype: object

# %% [markdown]
# # DataFrame Data Structure

# %%
df = pd.DataFrame(
    {
        'Name' : ['Ram','Shyam','Raju','Rani','Rahul'],
        'Age' : [12,15,13,21,18]
    }
)

# %%
df
# Out:
#     Name  Age
# 0    Ram   12
# 1  Shyam   15
# 2   Raju   13
# 3   Rani   21
# 4  Rahul   18

# %%
df.to_csv('output.csv',index=False)

# %% [markdown]
# # Exploring Data in the DataSet

# %%
df.head()
# Out:
#     Name  Age
# 0    Ram   12
# 1  Shyam   15
# 2   Raju   13
# 3   Rani   21
# 4  Rahul   18
