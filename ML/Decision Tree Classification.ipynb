# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
X = iris.data

# %%
y = iris.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9666666666666667

# %%
from sklearn.tree import plot_tree

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 30,10

plot_tree(clf)
# Out:
# [Text(0.375, 0.9375, 'x[2] <= 2.45\ngini = 0.666\nsamples = 120\nvalue = [41, 42, 37]'),
#  Text(0.25, 0.8125, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.3125, 0.875, 'True  '),
#  Text(0.5, 0.8125, 'x[2] <= 4.75\ngini = 0.498\nsamples = 79\nvalue = [0.0, 42.0, 37.0]'),
#  Text(0.4375, 0.875, '  False'),
#  Text(0.25, 0.6875, 'x[3] <= 1.65\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(0.125, 0.5625, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.375, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.75, 0.6875, 'x[2] <= 5.05\ngini = 0.214\nsamples = 41\nvalue = [0, 5, 36]'),
#  Text(0.625, 0.5625, 'x[0] <= 6.5\ngini = 0.496\nsamples = 11\nvalue = [0, 5, 6]'),
#  Text(0.5, 0.4375, 'x[1] <= 3.1\ngini = 0.375\nsamples = 8\nvalue = [0, 2, 6]'),
#  Text(0.375, 0.3125, 'x[0] <= 6.25\ngini = 0.245\nsamples = 7\nvalue = [0, 1, 6]'),
#  Text(0.25, 0.1875, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.5, 0.1875, 'x[3] <= 1.65\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.375, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.625, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.625, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.75, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.875, 0.5625, 'gini = 0.0\nsamples = 30\nvalue = [0, 0, 30]')]
